# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Griselda\Desktop\Bootcamp Data Analytics\Sprint 10\Qualitat Aire - BCN.csv")
df = df.iloc[:, :-1] # eliminar l'última columna
df.head()
# Out:
#    CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 0             8.0  Barcelona           19.0  Barcelona      4.0
# 1             8.0  Barcelona           19.0  Barcelona      4.0
# 2             8.0  Barcelona           19.0  Barcelona      4.0
# 3             8.0  Barcelona           19.0  Barcelona      4.0
# 4             8.0  Barcelona           19.0  Barcelona      4.0
#
#    CODI_CONTAMINANT     ANY  MES  DIA  H01  ...  H20  V20  H21  V21  H22  V22  \
# 0               7.0  2019.0  4.0  2.0  1.0  ...  8.0    V  3.0    V  1.0    V
# 1               7.0  2019.0  4.0  3.0  1.0  ...  3.0    V  2.0    V  2.0    V
# 2               7.0  2019.0  4.0  4.0  1.0  ...  2.0    V  2.0    V  1.0    V
# 3               7.0  2019.0  4.0  5.0  2.0  ...  3.0    V  2.0    V  2.0    V
# 4               7.0  2019.0  4.0  6.0  1.0  ...  6.0    V  2.0    V  2.0    V
#
#    H23  V23  H24  V24
# 0  1.0    V  1.0    V
# 1  2.0    V  2.0    V
# 2  2.0    V  2.0    V
# 3  1.0    V  2.0    V
# 4  1.0    V  3.0    V
#
# [5 rows x 57 columns]

# %%
codes_to_remove = [999, 998, 997, 996, 22, 101, 106, 107, 108, 109, 110, 112, 114, 7, 8]

df = df[~df["CODI_CONTAMINANT"].isin(codes_to_remove)] #eliminar els codis per innecessaris o repetits

# %%
df[df.isnull().any(axis=1)]
# Out:
#         CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 58                 8.0  Barcelona           19.0  Barcelona      4.0
# 61                 8.0  Barcelona           19.0  Barcelona      4.0
# 66                 8.0  Barcelona           19.0  Barcelona      4.0
# 82                 8.0  Barcelona           19.0  Barcelona      4.0
# 84                 8.0  Barcelona           19.0  Barcelona      4.0
# ...                ...        ...            ...        ...      ...
# 117606             8.0  Barcelona           19.0  Barcelona     58.0
# 117614             8.0  Barcelona           19.0  Barcelona     58.0
# 117617             8.0  Barcelona           19.0  Barcelona     58.0
# 117637             8.0  Barcelona           19.0  Barcelona     58.0
# 117645             8.0  Barcelona           19.0  Barcelona     58.0
#
#         CODI_CONTAMINANT     ANY   MES   DIA   H01  ...    H20  V20   H21  \
# 58                  10.0  2019.0   4.0   2.0  19.0  ...  116.0    V  51.0
# 61                  10.0  2019.0   4.0   5.0  20.0  ...   31.0    V  28.0
# 66                  10.0  2019.0   4.0  10.0  11.0  ...   13.0    V  14.0
# 82                  10.0  2019.0   4.0  26.0  10.0  ...   31.0    V  19.0
# 84                  10.0  2019.0   4.0  28.0  16.0  ...    NaN    N   NaN
# ...                  ...     ...   ...   ...   ...  ...    ...  ...   ...
# 117606              12.0  2024.0  12.0   5.0   4.0  ...    9.0    V   6.0
# 117614              12.0  2024.0  12.0  13.0   3.0  ...   17.0    V  17.0
# 117617              12.0  2024.0  12.0  16.0   7.0  ...   10.0    V   9.0
# 117637              14.0  2024.0  12.0   5.0  58.0  ...   55.0    V  63.0
# 117645              14.0  2024.0  12.0  13.0  68.0  ...   56.0    V  61.0
#
#         V21   H22  V22   H23  V23   H24  V24
# 58        V  30.0    V  18.0    V  19.0    V
# 61        V  19.0    V  12.0    V  12.0    V
# 66        V  16.0    V  19.0    V  25.0    V
# 82        V  19.0    V  18.0    V  18.0    V
# 84        N   NaN    N   NaN    N   NaN    N
# ...     ...   ...  ...   ...  ...   ...  ...
# 117606    V   7.0    V   9.0    V   8.0    V
# 117614    V  14.0    V  14.0    V  14.0    V
# 117617    V   8.0    V   8.0    V   7.0    V
# 117637    V  59.0    V  53.0    V  51.0    V
# 117645    V  57.0    V  57.0    V  49.0    V
#
# [20050 rows x 57 columns]

# %%
df
# Out:
#         CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 58                 8.0  Barcelona           19.0  Barcelona      4.0
# 59                 8.0  Barcelona           19.0  Barcelona      4.0
# 60                 8.0  Barcelona           19.0  Barcelona      4.0
# 61                 8.0  Barcelona           19.0  Barcelona      4.0
# 62                 8.0  Barcelona           19.0  Barcelona      4.0
# ...                ...        ...            ...        ...      ...
# 117659             8.0  Barcelona           19.0  Barcelona     58.0
# 117660             8.0  Barcelona           19.0  Barcelona     58.0
# 117661             8.0  Barcelona           19.0  Barcelona     58.0
# 117662             8.0  Barcelona           19.0  Barcelona     58.0
# 117663             8.0  Barcelona           19.0  Barcelona     58.0
#
#         CODI_CONTAMINANT     ANY   MES   DIA   H01  ...    H20  V20   H21  \
# 58                  10.0  2019.0   4.0   2.0  19.0  ...  116.0    V  51.0
# 59                  10.0  2019.0   4.0   3.0  18.0  ...   15.0    V  17.0
# 60                  10.0  2019.0   4.0   4.0   8.0  ...   23.0    V  20.0
# 61                  10.0  2019.0   4.0   5.0  20.0  ...   31.0    V  28.0
# 62                  10.0  2019.0   4.0   6.0   8.0  ...   16.0    V  14.0
# ...                  ...     ...   ...   ...   ...  ...    ...  ...   ...
# 117659              14.0  2024.0  12.0  27.0  47.0  ...   56.0    V  22.0
# 117660              14.0  2024.0  12.0  28.0  68.0  ...   51.0    V  56.0
# 117661              14.0  2024.0  12.0  29.0  66.0  ...   66.0    V  67.0
# 117662              14.0  2024.0  12.0  30.0  86.0  ...   69.0    V  66.0
# 117663              14.0  2024.0  12.0  31.0  70.0  ...   66.0    V  69.0
#
#         V21   H22  V22   H23  V23   H24  V24
# 58        V  30.0    V  18.0    V  19.0    V
# 59        V   9.0    V  10.0    V  13.0    V
# 60        V  17.0    V  16.0    V  20.0    V
# 61        V  19.0    V  12.0    V  12.0    V
# 62        V  17.0    V  17.0    V  19.0    V
# ...     ...   ...  ...   ...  ...   ...  ...
# 117659    V  16.0    V  47.0    V  64.0    V
# 117660    V  59.0    V  61.0    V  66.0    V
# 117661    V  70.0    V  71.0    V  79.0    V
# 117662    V  46.0    V  38.0    V  60.0    V
# 117663    V  68.0    V  70.0    V  76.0    V
#
# [62016 rows x 57 columns]
